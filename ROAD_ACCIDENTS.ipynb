# %% [markdown]
# **LOADING LIBRARIES AND DATASET**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from google.colab import files
files.upload()

# %%
# LOAD THE CSV FILE
df=pd.read_csv("/content/RTA Dataset.csv")
df
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
df.shape
# Out:
# (12316, 32)

# %%
df.size
# Out:
# 394112

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                     NaN  ...
# ...

# %%
df.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# ...

# %%
# CHECKING NUMERICAL COLUMNS IN THE DATA
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
df.describe(include='all')
# Out:
#             Time Day_of_week Age_band_of_driver Sex_of_driver  \
# count      12316       12316              12316         12316
# unique      1074           7                  5             3
# top     15:30:00      Friday              18-30          Male
# freq         120        2041               4271         11437
# mean         NaN         NaN                NaN           NaN
# std          NaN         NaN                NaN           NaN
# min          NaN         NaN                NaN           NaN
# 25%          NaN         NaN                NaN           NaN
# 50%          NaN         NaN                NaN           NaN
# 75%          NaN         NaN                NaN           NaN
# max          NaN         NaN                NaN           NaN
#
#          Educational_level Vehicle_driver_relation Driving_experience  \
# count                11575                   11737              11487
# unique                   7                       4                  7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %%
# FIND DUPLICATED VALUES
df.duplicated().sum()
# Out:
# 0

# %%
# HANDLING MISSING VALUES
df.isna().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
# DROP COLUMNS WITH MORE THAN 2500 MISSING VALUES AND TIME COLUMN(BCOS IT DOESNT PROVIDE MUCH INFORMATION)
df.drop(['Time','Service_year_of_vehicle','Defect_of_vehicle',\
         'Work_of_casuality','Fitness_of_casuality'],axis=1,inplace=True)
df.head()
# Out:
#   Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0      Monday              18-30          Male   Above high school
# 1      Monday              31-50          Male  Junior high school
# 2      Monday              18-30          Male  Junior high school
# 3      Sunday              18-30          Male  Junior high school
# 4      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Area_accident_occured   Lanes_or_Medians  ...  \
# 0            Owner     Residential areas                NaN  ...
# ...

# %%
# STORING CATEGORICAL FEATURE TO A VARIABLE
cat=[i for i in df.columns if df[i].dtype=='O']
print("ALL CATEGORICAL FEATURES IN DF:",cat)
# Out:
# ALL CATEGORICAL FEATURES IN DF: ['Day_of_week', 'Age_band_of_driver', 'Sex_of_driver', 'Educational_level', 'Vehicle_driver_relation', 'Driving_experience', 'Type_of_vehicle', 'Owner_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment', 'Types_of_Junction', 'Road_surface_type', 'Road_surface_conditions', 'Light_conditions', 'Weather_conditions', 'Type_of_collision', 'Vehicle_movement', 'Casualty_class', 'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity', 'Pedestrian_movement', 'Cause_of_accident', 'Accident_severity']

# %%
# REPLACE NULL VALUES IN THESE CATEGORICAL FEATURES WITH MODE VALUES
for i in cat:
  df[i].fillna(df[i].mode()[0],inplace=True)

# %%
# CHECK FOR NULL VALUES
df.isna().sum()
# Out:
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %% [markdown]
# **VISUALIZATION**

# %%
# FINDING THE CORRELATION BETWWEN THE NUMERICAL COLUMNS
df.corr()
# Out:
#                              Number_of_vehicles_involved  Number_of_casualties
# Number_of_vehicles_involved                     1.000000              0.213427
# Number_of_casualties                            0.213427              1.000000

# %%
# VISUALIZING THE DATASET (NUMERICAL PART)
sns.heatmap(df.corr(),annot=True)

# %%
sns.pairplot(df,hue='Accident_severity')

# %%
# JOINT PLOT
sns.jointplot(x='Number_of_casualties',y='Number_of_vehicles_involved',data=df)

# %% [markdown]
# **OBSERVATION: **
# NO CORRELATION BETWEEN NUMBER OF CASUALTIES AND NUMBER OF VEHICLES INVOLVED

# %%
# CHECKING THE DISTRIBUTION OF THE NUMERICAL COLUMNS
num_col=[i for i in df.columns if df[i].dtype!='O']
print("THE NUMERICAL COLUMNS ARE:",num_col)
# Out:
# THE NUMERICAL COLUMNS ARE: ['Number_of_vehicles_involved', 'Number_of_casualties']

# %%
# VISUALIZATION
plt.figure(figsize=[10,10])
plotnumber=1

for i in num_col:
  if plotnumber<=df.shape[1]:
    ax1=plt.subplot(2,2,plotnumber)
    plt.hist(df[i],color='blue')
    plt.grid()
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.title(i.upper(),fontsize=14,fontweight='bold')
  plotnumber+=1

# %% [markdown]
# **OBSERVATION:**
# MOST OF THE ACCIDENTS INVOLVE 2 VEHICLE
# MAJORITY OF THE ACCIDENTS HAVE 1 CASUALITY

# %%
# VISUALIZATION FOR CATEGORICAL COLUMNS: COUNT PLOT
plt.figure(figsize=[10,200])
plotnumber=1

for i in cat:
  if plotnumber<=df.shape[1] and i!='Accident_severity':
    ax1=plt.subplot(29,1,plotnumber)
    sns.countplot(y=i,data=df,palette='bright')
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.title(i.upper(),fontsize=14,fontweight='bold')
  plotnumber+=1

# %% [markdown]
# **HANDLING CATEGORICAL VALUES**

# %%
# COUNT DISTINCT VALUES IN EACH CATEGORIES
for i in cat:
  print("DISTINCT VALUES IN",i,"ARE:\n")
  print(df[i].value_counts())
  print("-"*50)
# Out:
# DISTINCT VALUES IN Time ARE:
#
# 15:30:00    120
# 17:10:00    110
# 18:30:00    103
# 11:30:00     99
# 17:00:00     98
#            ...
# 19:04:00      1
# 20:36:00      1
# 22:54:00      1
# 21:03:00      1
# 2:47:00       1
# Name: Time, Length: 1074, dtype: int64
# --------------------------------------------------
# DISTINCT VALUES IN Day_of_week ARE:
#
# Friday       2041
# Thursday     1851
# Wednesday    1840
# Tuesday      1770
# Monday       1681
# Saturday     1666
# Sunday       1467
# Name: Day_of_week, dtype: int64
# --------------------------------------------------
# DISTINCT VALUES IN Age_band_of_driver ARE:
#
# 18-30       4271
# 31-50       4087
# Over 51     1585
# Unknown     1548
# Under 18     825
# Name: Age_band_of_driver, dtype: int64
# --------------------------------------------------
# DISTINCT VALUES IN Sex_of_driver ARE:
#
# Male       11437
# Female       701
# Unknown      178
# Name: Sex_of_driver, dtype: int64
# ...

# %%
# AS THERE ARE MANY CATEGORICAL FEATURES WE NEED TO PERFORM FEATURE SELECTION
# USE CHI-SQARE METHOD:Chi-square between each feature and the target and select 
# the desired number of features with the best Chi-square scores

# %%
# STEP1: CONVERT CATEGORICAL FEATURES INTO INTEGERS USING LABEL ENCODING 
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
# CREATE A NEW DATAFRAME FOR PERFORMING CHI SQUARE ANALYSIS
df1=pd.DataFrame()

# %%
# CHECKING THE NEW DF: NOW ALL COLUMNS IN INTEGER
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Day_of_week              12316 non-null  int64
#  1   Age_band_of_driver       12316 non-null  int64
#  2   Sex_of_driver            12316 non-null  int64
#  3   Educational_level        12316 non-null  int64
#  4   Vehicle_driver_relation  12316 non-null  int64
#  5   Driving_experience       12316 non-null  int64
#  6   Type_of_vehicle          12316 non-null  int64
#  7   Owner_of_vehicle         12316 non-null  int64
#  8   Area_accident_occured    12316 non-null  int64
#  9   Lanes_or_Medians         12316 non-null  int64
#  10  Road_allignment          12316 non-null  int64
#  11  Types_of_Junction        12316 non-null  int64
#  12  Road_surface_type        12316 non-null  int64
#  13  Road_surface_conditions  12316 non-null  int64
# ...

# %%
# ENCODING ALL CATEGORICAL COLUMNS EXCEPT OUTPUT TO NEW DF
for i in cat:
  if i !='Accident_severity':
    df1[i]=le.fit_transform(df[i])

# %%
df1.head()
# Out:
#    Day_of_week  Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0            1                   0              1                  0
# 1            1                   1              1                  4
# 2            1                   0              1                  4
# 3            3                   0              1                  4
# 4            3                   0              1                  4
#
#    Vehicle_driver_relation  Driving_experience  Type_of_vehicle  \
# 0                        0                   0                0
# 1                        0                   3               11
# 2                        0                   0                5
# 3                        0                   2               11
# 4                        0                   1                0
#
#    Owner_of_vehicle  Area_accident_occured  Lanes_or_Medians  ...  \
# 0                 3                      9                 2  ...
# ...

# %%
# PERFORM CHI SQUARE TEST
from sklearn.feature_selection import chi2
f_p_scores=chi2(df1,df['Accident_severity'])

# %%
# PRINT F_SCORE AND P_VALUES
f_p_scores
# Out:
# (array([ 0.15822071,  8.91539214,  0.1431894 ,  0.17458477,  5.34534549,
#          4.49967858,  1.07767124,  1.10426215,  3.61654037,  3.28161464,
#          0.1319306 ,  3.08648691,  6.99480557,  0.61510308, 16.08282359,
#          1.14934538, 10.09632283,  2.20071197,  3.2168602 ,  0.12594479,
#         13.77841337,  0.20273788,  0.39747982,  3.19366551]),
#  array([9.23937958e-01, 1.15890328e-02, 9.30908116e-01, 9.16409114e-01,
#         6.90673790e-02, 1.05416165e-01, 5.83427189e-01, 5.75721597e-01,
#         1.63937473e-01, 1.93823502e-01, 9.36163348e-01, 2.13686893e-01,
#         3.02759144e-02, 7.35244973e-01, 3.21854237e-04, 5.62889079e-01,
#         6.42112839e-03, 3.32752607e-01, 2.00201664e-01, 9.38969394e-01,
#         1.01872169e-03, 9.03599597e-01, 8.19763078e-01, 2.02536988e-01]))

# %%
# FORM A NEW DF TO EVALUATE THE F_P_SCORES FOR FEATURE SELECTION
f_p_df=pd.DataFrame({'features':df1.columns,'f_score':f_p_scores[0],'p_values':f_p_scores[1]})
f_p_df
# Out:
#                    features    f_score  p_values
# 0               Day_of_week   0.158221  0.923938
# 1        Age_band_of_driver   8.915392  0.011589
# 2             Sex_of_driver   0.143189  0.930908
# 3         Educational_level   0.174585  0.916409
# 4   Vehicle_driver_relation   5.345345  0.069067
# 5        Driving_experience   4.499679  0.105416
# 6           Type_of_vehicle   1.077671  0.583427
# 7          Owner_of_vehicle   1.104262  0.575722
# 8     Area_accident_occured   3.616540  0.163937
# 9          Lanes_or_Medians   3.281615  0.193824
# 10          Road_allignment   0.131931  0.936163
# 11        Types_of_Junction   3.086487  0.213687
# 12        Road_surface_type   6.994806  0.030276
# 13  Road_surface_conditions   0.615103  0.735245
# 14         Light_conditions  16.082824  0.000322
# 15       Weather_conditions   1.149345  0.562889
# 16        Type_of_collision  10.096323  0.006421
# 17         Vehicle_movement   2.200712  0.332753
# ...

# %%
# WE MUST SELECT FEATURES WITH HIGH F_SCORE AND LOW P_VALUES
# SO SORT WITH P_VALUES IN ASC ORDER
f_p_df.sort_values(by='p_values',ascending=True)
# Out:
#                    features    f_score  p_values
# 14         Light_conditions  16.082824  0.000322
# 20     Age_band_of_casualty  13.778413  0.001019
# 16        Type_of_collision  10.096323  0.006421
# 1        Age_band_of_driver   8.915392  0.011589
# 12        Road_surface_type   6.994806  0.030276
# 4   Vehicle_driver_relation   5.345345  0.069067
# 5        Driving_experience   4.499679  0.105416
# 8     Area_accident_occured   3.616540  0.163937
# 9          Lanes_or_Medians   3.281615  0.193824
# 18           Casualty_class   3.216860  0.200202
# 23        Cause_of_accident   3.193666  0.202537
# 11        Types_of_Junction   3.086487  0.213687
# 17         Vehicle_movement   2.200712  0.332753
# 15       Weather_conditions   1.149345  0.562889
# 7          Owner_of_vehicle   1.104262  0.575722
# 6           Type_of_vehicle   1.077671  0.583427
# 13  Road_surface_conditions   0.615103  0.735245
# 22      Pedestrian_movement   0.397480  0.819763
# ...

# %%
# DROP FEATURES: WITH LOW F_SCORE
df2=df.drop(['Owner_of_vehicle','Type_of_vehicle','Road_surface_conditions',
             'Pedestrian_movement','Casualty_severity','Educational_level','Day_of_week','Sex_of_driver',
             'Road_allignment','Sex_of_casualty'],axis=1)
df2.head()
# Out:
#   Age_band_of_driver Vehicle_driver_relation Driving_experience  \
# 0              18-30                Employee              1-2yr
# 1              31-50                Employee         Above 10yr
# 2              18-30                Employee              1-2yr
# 3              18-30                Employee             5-10yr
# 4              18-30                Employee              2-5yr
#
#   Area_accident_occured                                  Lanes_or_Medians  \
# 0     Residential areas  Two-way (divided with broken lines road marking)
# 1          Office areas                                 Undivided Two way
# 2    Recreational areas                                             other
# 3          Office areas                                             other
# 4      Industrial areas                                             other
#
#   Types_of_Junction Road_surface_type       Light_conditions  \
# 0       No junction     Asphalt roads               Daylight
# ...

# %%
df2.shape
# Out:
# (12316, 17)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12316 entries, 0 to 12315
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age_band_of_driver           12316 non-null  object
#  1   Vehicle_driver_relation      12316 non-null  object
#  2   Driving_experience           12316 non-null  object
#  3   Area_accident_occured        12316 non-null  object
#  4   Lanes_or_Medians             12316 non-null  object
#  5   Types_of_Junction            12316 non-null  object
#  6   Road_surface_type            12316 non-null  object
#  7   Light_conditions             12316 non-null  object
#  8   Weather_conditions           12316 non-null  object
#  9   Type_of_collision            12316 non-null  object
#  10  Number_of_vehicles_involved  12316 non-null  int64
#  11  Number_of_casualties         12316 non-null  int64
#  12  Vehicle_movement             12316 non-null  object
# ...

# %%
# CHECK FOR MISSING VALUES
df2.isna().sum()
# Out:
# Age_band_of_driver             0
# Vehicle_driver_relation        0
# Driving_experience             0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Types_of_Junction              0
# Road_surface_type              0
# Light_conditions               0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Age_band_of_casualty           0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %%
# ASSIGNING CATEGORICAL FEATURES TO A VARIABLE
new_cat=[i for i in df2.columns if df2[i].dtype=='O']
print("ALL CATEGORICAL FEATURES IN NEW DF:",new_cat)
# Out:
# ALL CATEGORICAL FEATURES IN NEW DF: ['Age_band_of_driver', 'Vehicle_driver_relation', 'Driving_experience', 'Area_accident_occured', 'Lanes_or_Medians', 'Types_of_Junction', 'Road_surface_type', 'Light_conditions', 'Weather_conditions', 'Type_of_collision', 'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty', 'Cause_of_accident', 'Accident_severity']

# %%
# COUNT DISTINCT VALUES IN EACH CATEGORIES
for i in new_cat:
  print("DISTINCT VALUES IN",i,"ARE:\n")
  print(df2[i].value_counts())
  print("-"*50)
# Out:
# DISTINCT VALUES IN Age_band_of_driver ARE:
#
# 18-30       4271
# 31-50       4087
# Over 51     1585
# Unknown     1548
# Under 18     825
# Name: Age_band_of_driver, dtype: int64
# --------------------------------------------------
# DISTINCT VALUES IN Vehicle_driver_relation ARE:
#
# Employee    10206
# Owner        1973
# Other         123
# Unknown        14
# Name: Vehicle_driver_relation, dtype: int64
# --------------------------------------------------
# DISTINCT VALUES IN Driving_experience ARE:
#
# 5-10yr        4192
# 2-5yr         2613
# Above 10yr    2262
# 1-2yr         1756
# Below 1yr     1342
# No Licence     118
# unknown         33
# Name: Driving_experience, dtype: int64
# --------------------------------------------------
# DISTINCT VALUES IN Area_accident_occured ARE:
#
# Other                              4058
# Office areas                       3451
# Residential areas                  2060
#  Church areas                      1060
# ...

# %%
# CONVERTING THE CATEGORICAL FETURES TO INTEGERS
# GET DUMMY
dummy=pd.get_dummies(df2[['Age_band_of_driver', 'Vehicle_driver_relation', 'Driving_experience',
       'Area_accident_occured', 'Lanes_or_Medians', 'Types_of_Junction',
       'Road_surface_type', 'Light_conditions','Weather_conditions','Type_of_collision',
       'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty',
       'Cause_of_accident']],drop_first=True)

# %%
dummy.head(3)
# Out:
#    Age_band_of_driver_31-50  Age_band_of_driver_Over 51  \
# 0                         0                           0
# 1                         1                           0
# 2                         0                           0
#
#    Age_band_of_driver_Under 18  Age_band_of_driver_Unknown  \
# 0                            0                           0
# 1                            0                           0
# 2                            0                           0
#
#    Vehicle_driver_relation_Other  Vehicle_driver_relation_Owner  \
# 0                              0                              0
# 1                              0                              0
# 2                              0                              0
#
#    Vehicle_driver_relation_Unknown  Driving_experience_2-5yr  \
# 0                                0                         0
# 1                                0                         0
# ...

# %%
dummy.tail(3)
# Out:
#        Age_band_of_driver_31-50  Age_band_of_driver_Over 51  \
# 12313                         0                           1
# 12314                         0                           0
# 12315                         0                           0
#
#        Age_band_of_driver_Under 18  Age_band_of_driver_Unknown  \
# 12313                            0                           0
# 12314                            0                           0
# 12315                            0                           0
#
#        Vehicle_driver_relation_Other  Vehicle_driver_relation_Owner  \
# 12313                              0                              0
# 12314                              0                              0
# 12315                              0                              0
#
#        Vehicle_driver_relation_Unknown  Driving_experience_2-5yr  \
# 12313                                0                         0
# ...

# %%
# CONCATINATE DUMMY AND DF2
df3=pd.concat([df2,dummy],axis=1)

# %%
df3
# Out:
#       Age_band_of_driver Vehicle_driver_relation Driving_experience  \
# 0                  18-30                Employee              1-2yr
# 1                  31-50                Employee         Above 10yr
# 2                  18-30                Employee              1-2yr
# 3                  18-30                Employee             5-10yr
# 4                  18-30                Employee              2-5yr
# ...                  ...                     ...                ...
# 12311              31-50                Employee              2-5yr
# 12312            Unknown                Employee             5-10yr
# 12313            Over 51                Employee             5-10yr
# 12314              18-30                Employee         Above 10yr
# 12315              18-30                Employee             5-10yr
#
#       Area_accident_occured                                  Lanes_or_Medians  \
# ...

# %%
# DROP UNWANTED INITAIL COLUMNS
df3.drop(['Age_band_of_driver', 'Vehicle_driver_relation', 'Driving_experience',
       'Area_accident_occured', 'Lanes_or_Medians', 'Types_of_Junction',
       'Road_surface_type', 'Light_conditions', 'Type_of_collision','Weather_conditions',
       'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty',
       'Cause_of_accident'],axis=1,inplace=True)

# %%
# FINAL PURE DATASET
df3.head()
# Out:
#    Number_of_vehicles_involved  Number_of_casualties Accident_severity  \
# 0                            2                     2     Slight Injury
# 1                            2                     2     Slight Injury
# 2                            2                     2    Serious Injury
# 3                            2                     2     Slight Injury
# 4                            2                     2     Slight Injury
#
#    Age_band_of_driver_31-50  Age_band_of_driver_Over 51  \
# 0                         0                           0
# 1                         1                           0
# 2                         0                           0
# 3                         0                           0
# 4                         0                           0
#
#    Age_band_of_driver_Under 18  Age_band_of_driver_Unknown  \
# 0                            0                           0
# 1                            0                           0
# ...

# %%
# CHECK FOR MISSING VALUES
df3.isna().sum()
# Out:
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Accident_severity                0
# Age_band_of_driver_31-50         0
# Age_band_of_driver_Over 51       0
#                                 ..
# Cause_of_accident_Overspeed      0
# Cause_of_accident_Overtaking     0
# Cause_of_accident_Overturning    0
# Cause_of_accident_Turnover       0
# Cause_of_accident_Unknown        0
# Length: 105, dtype: int64

# %%
# SEPERATING INPUT X AND OUTPUT Y
x=df3.drop(['Accident_severity'],axis=1)

# %%
x.head(3)
# Out:
#    Number_of_vehicles_involved  Number_of_casualties  \
# 0                            2                     2
# 1                            2                     2
# 2                            2                     2
#
#    Age_band_of_driver_31-50  Age_band_of_driver_Over 51  \
# 0                         0                           0
# 1                         1                           0
# 2                         0                           0
#
#    Age_band_of_driver_Under 18  Age_band_of_driver_Unknown  \
# 0                            0                           0
# 1                            0                           0
# 2                            0                           0
#
#    Vehicle_driver_relation_Other  Vehicle_driver_relation_Owner  \
# 0                              0                              0
# 1                              0                              0
# 2                              0                              0
#
# ...

# %%
x.shape
# Out:
# (12316, 104)

# %%
y=df3['Accident_severity']

# %%
y.head()
# Out:
# 0     Slight Injury
# 1     Slight Injury
# 2    Serious Injury
# 3     Slight Injury
# 4     Slight Injury
# Name: Accident_severity, dtype: object

# %%
# COUNT THE OCCURENCES IN OUTPUT 
y.value_counts()
# Out:
# Slight Injury     10415
# Serious Injury     1743
# Fatal injury        158
# Name: Accident_severity, dtype: int64

# %%
# PLOT THE OUTPUT FREQUENCY USING SEABORN
sns.countplot(y,palette='magma')

# %%
# WE CAN SEE THAT THE OUTPUT COUNTS ARE NOT WITHIN THE SAME RANGE 
# SO TO IMPROVE MODEL ACCURACY PERFORM UNDERSAMPLING OR OVERSAMPLING

# OVERSAMPLING
from imblearn.over_sampling import SMOTE
oversample=SMOTE()
xo,yo=oversample.fit_resample(x,y)

# %%
# CHECKING THE OUPUT AFTER OVERSAMPLING
y1=pd.DataFrame(yo)
y1.value_counts()
# Out:
# Accident_severity
# Fatal injury         10415
# Serious Injury       10415
# Slight Injury        10415
# dtype: int64

# %%
# SPLITTING DATA TO TRAIN TEST (TRAIN=70% TEST=30%)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(xo,yo,test_size=0.30,random_state=42)

# %% [markdown]
# **MODEL CREATION**

# %%
# KNN 
from sklearn.neighbors import KNeighborsClassifier
model_knn=KNeighborsClassifier()
model_knn.fit(x_train,y_train)
y_knn=model_knn.predict(x_test)
y_knn
# Out:
# array(['Serious Injury', 'Serious Injury', 'Slight Injury', ...,
#        'Fatal injury', 'Serious Injury', 'Serious Injury'], dtype=object)

# %%
# PERFORMANCE EVALUATION
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,accuracy_score,classification_report
mat=confusion_matrix(y_test,y_knn)
mat
# Out:
# array([[3124,    2,    0],
#        [ 259, 2856,   29],
#        [ 543, 1597,  964]])

# %%
print(ConfusionMatrixDisplay.from_predictions(y_test,y_knn))

# %%
score_knn=accuracy_score(y_test,y_knn)
score_knn
# Out:
# 0.7407723490505654

# %%
report=classification_report(y_test,y_knn)
print(report)
# Out:
#                 precision    recall  f1-score   support
#
#   Fatal injury       0.80      1.00      0.89      3126
# Serious Injury       0.64      0.91      0.75      3144
#  Slight Injury       0.97      0.31      0.47      3104
#
#       accuracy                           0.74      9374
#      macro avg       0.80      0.74      0.70      9374
#   weighted avg       0.80      0.74      0.70      9374

# %%
# NAIVE BAYES
from sklearn.naive_bayes import MultinomialNB
model_nb=MultinomialNB()
model_nb.fit(x_train,y_train)
y_nb=model_nb.predict(x_test)
y_nb
# Out:
# array(['Fatal injury', 'Slight Injury', 'Serious Injury', ...,
#        'Fatal injury', 'Serious Injury', 'Slight Injury'], dtype='<U14')

# %%
# PERFORMANCE EVALUATION
mat_nb=confusion_matrix(y_test,y_nb)
mat_nb
# Out:
# array([[2297,  675,  154],
#        [ 707, 1643,  794],
#        [ 206,  819, 2079]])

# %%
print(ConfusionMatrixDisplay.from_predictions(y_test,y_nb))

# %%
score_nb=accuracy_score(y_test,y_nb)

# %%
report_nb=classification_report(y_test,y_nb)
print(report_nb)
# Out:
#                 precision    recall  f1-score   support
#
#   Fatal injury       0.72      0.73      0.73      3126
# Serious Injury       0.52      0.52      0.52      3144
#  Slight Injury       0.69      0.67      0.68      3104
#
#       accuracy                           0.64      9374
#      macro avg       0.64      0.64      0.64      9374
#   weighted avg       0.64      0.64      0.64      9374

# %%
# SVM
from sklearn.svm import SVC
model_svm=SVC()
model_svm.fit(x_train,y_train)
y_svm=model_svm.predict(x_test)
y_svm
# Out:
# array(['Serious Injury', 'Slight Injury', 'Slight Injury', ...,
#        'Fatal injury', 'Serious Injury', 'Slight Injury'], dtype=object)

# %%
# PERFORMANCE EVALUATION
mat_svm=confusion_matrix(y_test,y_svm)
mat_svm
# Out:
# array([[3004,   83,   39],
#        [ 247, 2323,  574],
#        [  10,  242, 2852]])

# %%
print(ConfusionMatrixDisplay.from_predictions(y_test,y_svm))

# %%
score_svm=accuracy_score(y_test,y_svm)
score_svm
# Out:
# 0.8725197354384467

# %%
report_svm=classification_report(y_test,y_svm)
print(report_svm)
# Out:
#                 precision    recall  f1-score   support
#
#   Fatal injury       0.92      0.96      0.94      3126
# Serious Injury       0.88      0.74      0.80      3144
#  Slight Injury       0.82      0.92      0.87      3104
#
#       accuracy                           0.87      9374
#      macro avg       0.87      0.87      0.87      9374
#   weighted avg       0.87      0.87      0.87      9374

# %%
# DECISION TREE
from sklearn.tree import DecisionTreeClassifier
model_tree=DecisionTreeClassifier(criterion='entropy')
model_tree.fit(x_train,y_train)
y_tree=model_tree.predict(x_test)
y_tree
# Out:
# array(['Serious Injury', 'Slight Injury', 'Slight Injury', ...,
#        'Fatal injury', 'Serious Injury', 'Slight Injury'], dtype=object)

# %%
# PERFORMANCE EVALUATION
mat_tree=confusion_matrix(y_test,y_tree)
mat_tree
# Out:
# array([[3099,   10,   17],
#        [  54, 2693,  397],
#        [  79,  777, 2248]])

# %%
print(ConfusionMatrixDisplay.from_predictions(y_test,y_tree))

# %%
score_tree=accuracy_score(y_test,y_tree)
score_tree
# Out:
# 0.8576914870919565

# %%
report_tree=classification_report(y_test,y_tree)
print(report_tree)
# Out:
#                 precision    recall  f1-score   support
#
#   Fatal injury       0.96      0.99      0.97      3126
# Serious Injury       0.77      0.86      0.81      3144
#  Slight Injury       0.84      0.72      0.78      3104
#
#       accuracy                           0.86      9374
#      macro avg       0.86      0.86      0.86      9374
#   weighted avg       0.86      0.86      0.86      9374

# %%
# RANDOM FOREST 
from sklearn.ensemble import RandomForestClassifier
model_random=RandomForestClassifier(n_estimators=5,criterion='entropy')
model_random.fit(x_train,y_train)
y_random=model_random.predict(x_test)

# %%
# PERFORMANCE EVALUATION
mat_random=confusion_matrix(y_test,y_random)
mat_random
# Out:
# array([[3105,   11,   10],
#        [  53, 2756,  335],
#        [  56,  741, 2307]])

# %%
print(ConfusionMatrixDisplay.from_predictions(y_test,y_random))

# %%
score_random=accuracy_score(y_test,y_random)
score_random
# Out:
# 0.8713462769362065

# %%
report_random=classification_report(y_test,y_random)
print(report_random)
# Out:
#                 precision    recall  f1-score   support
#
#   Fatal injury       0.97      0.99      0.98      3126
# Serious Injury       0.79      0.88      0.83      3144
#  Slight Injury       0.87      0.74      0.80      3104
#
#       accuracy                           0.87      9374
#      macro avg       0.87      0.87      0.87      9374
#   weighted avg       0.87      0.87      0.87      9374

# %%
# COMPARING ACCURACY SCORES OF VARIOUS CLASSIFICATION ALGORITHMS
algorithms=["knn","naive_bayes","svm","decisiion_tree","random_forest"]
accuracy=[score_knn,score_nb,score_svm,score_tree,score_random]
accuracy_df=pd.DataFrame({'ALGORITHM':algorithms,"ACCURACY":accuracy})
accuracy_df.ACCURACY=accuracy_df.ACCURACY*100
accuracy_df.sort_values(by='ACCURACY',ascending=False,inplace=True)
accuracy_df
# Out:
#         ALGORITHM   ACCURACY
# 2             svm  87.251974
# 4   random_forest  87.134628
# 3  decisiion_tree  85.769149
# 0             knn  74.077235
# 1     naive_bayes  64.209516

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='ALGORITHM',y='ACCURACY',data=accuracy_df,palette='muted')
font={'family':'serif','color':'black','size':20,'fontweight':'bold'} 
plt.title("COMPARING THE ACCURACIES OF THE CLASSIFIACTION ALGORITHMS",fontdict=font)
plt.ylabel("ACCURACY SCORES")
plt.show()
